# %%
import os
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
filename_func = "random_func_samples.bin"
filename_ran3 = "random_ran3_samples.bin"

write_option = 0
read_option = 0
num_samples = 40000000

# %%
os.system("rm {}".format(filename_func))
os.system("../../c_lang/tests/test_random_func {} {} {} {}".format(filename_func, num_samples, write_option, read_option))
# Out:
# 0

# %%
os.system("rm {}".format(filename_ran3))
os.system("../../c_lang/tests/test_random_ran3 {} {} {} {}".format(filename_ran3, num_samples, write_option, read_option))
# Out:
# 0

# %%
def load_data_from_bin(filename, cols=4):
    with open(filename, "rb") as file:
        data_bin = file.read()
    
    data_np = np.frombuffer(data_bin, dtype=np.float)
    data_np = np.reshape(data_np, (int(data_np.shape[0]/cols), cols))
    del data_bin
    return data_np

# %%
data = load_data_from_bin("random_func_samples.bin", 4)

# %%
data.shape
# Out:
# (40000000, 4)

# %%
sns.distplot(data[:,0], kde=False)
plt.show()

# %%
sns.distplot(data[:,1], kde=False)
plt.show()

# %%
sns.distplot(data[:,2], kde=False)
plt.show()

# %%
sns.distplot(data[:,3], kde=False)
plt.show()

# %%
data_ran3 = load_data_from_bin("random_ran3_samples.bin", 3)

# %%
data_ran3.shape
# Out:
# (40000000, 3)

# %%
sns.distplot(data_ran3[:,0], kde=False)
plt.show()

# %%
sns.distplot(data_ran3[:,1], kde=False)
plt.show()

# %%
sns.distplot(data_ran3[:,2], kde=False)
plt.show()
